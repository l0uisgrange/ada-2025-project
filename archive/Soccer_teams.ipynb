# %% [markdown]
# # Soccer Teams Exploratory Data Analysis (EDA)

# %%
# Automatically reloads modules when you make changes (useful during development)
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import sys, os
sys.path.append(os.path.abspath('..'))

from src.data import load_data
df_body, df_title, df_subreddits, df_english_pl, df_esports, df_superbowl = load_data()

# %%
df_english_pl
# Out:
#        Season              DateTime        HomeTeam     AwayTeam  FTHG  FTAG  \
# 0     2013-14  2014-01-01T00:00:00Z         Arsenal      Cardiff     2     0
# 1     2013-14  2014-01-01T00:00:00Z  Crystal Palace      Norwich     1     1
# 2     2013-14  2014-01-01T00:00:00Z          Fulham     West Ham     2     1
# 3     2013-14  2014-01-01T00:00:00Z       Liverpool         Hull     2     0
# 4     2013-14  2014-01-01T00:00:00Z      Man United    Tottenham     1     2
# ...       ...                   ...             ...          ...   ...   ...
# 1284  2016-17  2017-04-29T00:00:00Z  Crystal Palace      Burnley     0     2
# 1285  2016-17  2017-04-29T00:00:00Z     Southampton         Hull     0     0
# 1286  2016-17  2017-04-29T00:00:00Z           Stoke     West Ham     0     0
# 1287  2016-17  2017-04-29T00:00:00Z      Sunderland  Bournemouth     0     1
# 1288  2016-17  2017-04-29T00:00:00Z       West Brom    Leicester     0     1
#
# ...

# %%
df_superbowl
# Out:
#          Date           SB                Winner  Winner Pts  \
# 0  Feb 5 2017      LI (51)  New England Patriots          34
# 1  Feb 7 2016           50        Denver Broncos          24
# 2  Feb 1 2015    XLIX (49)  New England Patriots          28
# 3  Feb 2 2014  XLVIII (48)      Seattle Seahawks          43
#
#                Loser  Loser Pts            MVP                        Stadium  \
# 0    Atlanta Falcons         28      Tom Brady                    NRG Stadium
# 1  Carolina Panthers         10     Von Miller                 Levi's Stadium
# 2   Seattle Seahawks         24      Tom Brady  University of Phoenix Stadium
# 3     Denver Broncos          8  Malcolm Smith                MetLife Stadium
#
#               City       State
# 0          Houston       Texas
# 1      Santa Clara  California
# 2         Glendale     Arizona
# 3  East Rutherford  New Jersey

# %%
# For title dataset
source_title_subs = df_title["SOURCE_SUBREDDIT"].unique()
target_title_subs = df_title["TARGET_SUBREDDIT"].unique()

# For body dataset
source_body_subs = df_body["SOURCE_SUBREDDIT"].unique()
target_body_subs = df_body["TARGET_SUBREDDIT"].unique()

print("SOURCE (title):", source_title_subs)
print("TARGET (title):", target_title_subs)
print("SOURCE (body):", source_body_subs)
print("TARGET (body):", target_body_subs)
# Out:
# SOURCE (title): ['rddtgaming' 'xboxone' 'ps4' ... 'uplifting_news' 'medicinalherbs'
#  'mintsim']
# TARGET (title): ['rddtrust' 'battlefield_4' 'leangains' ... 'seriousvr' 'mattgray'
#  'noshitouija']
# SOURCE (body): ['leagueoflegends' 'theredlion' 'inlandempire' ... 'daddyofive'
#  'noshitouija' 'mildlynomil']
# TARGET (body): ['teamredditteams' 'soccer' 'bikela' ... 'hatedaddyofive' 'ouija_irl'
#  'wholesomeouija']

# %%
subreddit = "nfl"
# subreddit = "hockey"
# subbredit = "nba"
# subreddit = "baseball"
# subreddit = "cfb"
